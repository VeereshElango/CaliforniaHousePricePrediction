# %% [markdown]
# <a href="https://colab.research.google.com/github/VeereshElango/CaliforniaHousePricePrediction/blob/master/open_mmfashion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone --recursive https://github.com/open-mmlab/mmfashion.git
# Out:
# Cloning into 'mmfashion'...
# remote: Enumerating objects: 502, done.
# remote: Counting objects: 100% (502/502), done.
# remote: Compressing objects: 100% (324/324), done.
# remote: Total 2570 (delta 288), reused 342 (delta 169), pack-reused 2068
# Receiving objects: 100% (2570/2570), 11.55 MiB | 13.88 MiB/s, done.
# Resolving deltas: 100% (1687/1687), done.
# Submodule 'mmdetection' (https://github.com/open-mmlab/mmdetection.git) registered for path 'mmdetection'
# Cloning into '/content/mmfashion/mmdetection'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 10608 (delta 2), reused 2 (delta 0), pack-reused 10592
# Receiving objects: 100% (10608/10608), 9.02 MiB | 11.79 MiB/s, done.
# Resolving deltas: 100% (7107/7107), done.
# Submodule path 'mmdetection': checked out '502c5513a4a70368151c0fb9f1367ac61e0afdbf'
# ...

# %%
% cd mmfashion
! python setup.py install
# Out:
# /content/mmfashion
# running install
# running bdist_egg
# running egg_info
# creating mmfashion.egg-info
# writing mmfashion.egg-info/PKG-INFO
# writing dependency_links to mmfashion.egg-info/dependency_links.txt
# writing requirements to mmfashion.egg-info/requires.txt
# writing top-level names to mmfashion.egg-info/top_level.txt
# writing manifest file 'mmfashion.egg-info/SOURCES.txt'
# writing manifest file 'mmfashion.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/mmfashion
# copying mmfashion/__init__.py -> build/lib/mmfashion
# copying mmfashion/version.py -> build/lib/mmfashion
# creating build/lib/mmfashion/datasets
# copying mmfashion/datasets/__init__.py -> build/lib/mmfashion/datasets
# copying mmfashion/datasets/builder.py -> build/lib/mmfashion/datasets
# copying mmfashion/datasets/Landmark_Detect.py -> build/lib/mmfashion/datasets
# ...

# %%
! ls
# Out:
# build	 demo	 docs	  mmdetection	      README.md		setup.py
# configs  dist	 LICENSE  mmfashion	      requirements	tools
# data	 docker  misc	  mmfashion.egg-info  requirements.txt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
! mkdir ./data/Attr_Predict

# %%
! mkdir ./data/Attr_Predict/Anno
# Out:
# mkdir: cannot create directory ‘./data/Attr_Predict/Anno’: File exists

# %%
! cp ../gdrive/My\ Drive/ColabDatasets/mmfashion_trained_models/attribute_predict/global_vgg/Anno/*.* data/Attr_Predict/Anno/

# %%
# Prepare `Anno/list_attr_cloth.txt` which is specified in `configs/attribute_predict/global_predictor_vgg_attr.py`
! python demo/test_predictor.py --input demo/imgs/attr_pred_demo2.jpg --checkpoint ../gdrive/My\ Drive/ColabDatasets/mmfashion_trained_models/attribute_predict/global_vgg/latest.pth
# Out:
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: roi_pool.linear.0.weight, roi_pool.linear.0.bias, concat.fc_fusion.weight, concat.fc_fusion.bias
#
# [ Top3 Prediction ]
# sleeve
# knit
# maxi
# [ Top5 Prediction ]
# sleeve
# knit
# maxi
# lace
# striped
# [ Top10 Prediction ]
# sleeve
# knit
# maxi
# lace
# striped
# denim
# print
# stripe
# leather
# mesh
